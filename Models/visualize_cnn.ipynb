[430.1938431937308,12, 60, 16],
[403.86544016389735,12, 60, 32],
[395.3388172355287,12, 60, 64],
[471.87450254042085,12, 60, 128],
[403.589183588411,12, 70, 16],
[376.9052172582282,12, 70, 32],
[399.7760274899448,12, 70, 64],
[370.4079650433691,12, 70, 128],
[391.91415528173707,12, 80, 16],
[378.42308084452105,12, 80, 32],
[383.9155785792212,12, 80, 64],
[395.8633246221261,12, 80, 128],
[398.4251070412149,12, 90, 16],
[380.08415535588745,12, 90, 32],
[376.65185320975127,12, 90, 64],
[388.6496150182814,12, 90, 128],
[400.60131085463667,12, 100, 16],
[348.7109360461028,12, 100, 32],
[408.0701001290104,12, 100, 64],
[353.7750279564565,12, 100, 128],
[403.368612302791,12, 110, 16],
[394.4928234536011,12, 110, 32],
[361.4466150579125,12, 110, 64],
[382.14344888916594,12, 110, 128],
[372.82774469743214,12, 120, 16],
[382.2044539950704,12, 120, 32],
[398.4469917345755,12, 120, 64],
[489.48385512296056,12, 120, 128]
]

# %%
sx_16 = {}
sx_32 = {}
sx_64 = {}
sx_128 = {}
et_16 = {}
et_32 = {}
et_64 = {}
et_128 = {}
el_16 = {}
el_32 = {}
el_64 = {}
el_128 = {}
min_val = 10000
min_array = [0,0,0]
for item in lst:
  if item[0] > 700:
    continue
  if min_val > item[0]:
    min_val = item[0]
    min_array[0] = item[1]
    min_array[1] = item[2]
    min_array[2] = item[3]
  if item[1] == 6:
    if item[3] == 16:
      sx_16[item[2]] = item[0]
    elif item[3] == 32:
      sx_32[item[2]] = item[0]
    elif item[3] == 64:
      sx_64[item[2]] = item[0]
    elif item[3] == 128:
      sx_128[item[2]] = item[0]
  elif item[1] == 8:
    if item[3] == 16:
      et_16[item[2]] = item[0]
    elif item[3] == 32:
      et_32[item[2]] = item[0]
    elif item[3] == 64:
      et_64[item[2]] = item[0]
    elif item[3] == 128:
      et_128[item[2]] = item[0]
  elif item[1] == 12:
    if item[3] == 16:
      el_16[item[2]] = item[0]
    elif item[3] == 32:
      el_32[item[2]] = item[0]
    elif item[3] == 64:
      el_64[item[2]] = item[0]
    elif item[3] == 128:
      el_128[item[2]] = item[0]
min_val, min_array
# Out:
# (348.7109360461028, [12, 100, 32])

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(18,8))
fig.suptitle('Horizontally stacked subplots')
plt.figure(figsize=(1,1))
ax1.plot(list(sx_16.keys()), list(sx_16.values()), label = "Filter Size = 16")
ax1.plot(list(sx_32.keys()), list(sx_32.values()), label = "Filter Size = 32")
ax1.plot(list(sx_64.keys()), list(sx_64.values()), label = "Filter Size = 64")
ax1.plot(list(sx_128.keys()), list(sx_128.values()), label = "Filter Size = 128")
ax1.legend(loc="upper left")

ax2.plot(list(et_16.keys()), list(et_16.values()), label = "Filter Size = 16")
ax2.plot(list(et_32.keys()), list(et_32.values()), label = "Filter Size = 32")
ax2.plot(list(et_64.keys()), list(et_64.values()), label = "Filter Size = 64")
ax2.plot(list(et_128.keys()), list(et_128.values()), label = "Filter Size = 128")
ax2.legend(loc="upper right")

ax3.plot(list(el_16.keys()), list(el_16.values()), label = "Filter Size = 16")
ax3.plot(list(el_32.keys()), list(el_32.values()), label = "Filter Size = 32")
ax3.plot(list(el_64.keys()), list(el_64.values()), label = "Filter Size = 64")
ax3.plot(list(el_128.keys()), list(el_128.values()), label = "Filter Size = 128")
ax3.legend(loc="upper left")

#ax2.plot(list(eight_step_list.keys()), list(eight_step_list.values()))
#ax3.plot(list(twelve_step_list.keys()), list(twelve_step_list.values()))
plt.setp(ax1, xlabel='Number of LSTM Units')
plt.setp(ax2, xlabel='Number of LSTM Units')
plt.setp(ax3, xlabel='Number of LSTM Units')
plt.setp(ax1, ylabel='RMSE')
# Out:
# [Text(0, 0.5, 'RMSE')]
